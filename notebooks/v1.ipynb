# %%
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline

data = '../data/raw/MLChallengeData.csv'

# %% [markdown]
# ### Load and Explore

# %%
df = pandas.read_csv(data)

# %%
df.describe()
# Out:
#             Status             Id    Refreshing        Runner         Baker  \
# count  3218.000000   35644.000000  35644.000000  35644.000000  35644.000000
# mean      0.334058  174318.010240      0.051341      0.045926      0.000870
# std       0.471734   65871.282306      0.220695      0.209328      0.029478
# min       0.000000      25.000000      0.000000      0.000000      0.000000
# 25%       0.000000  128975.500000      0.000000      0.000000      0.000000
# 50%       0.000000  157081.500000      0.000000      0.000000      0.000000
# 75%       1.000000  174588.500000      0.000000      0.000000      0.000000
# max       1.000000  298442.000000      1.000000      1.000000      1.000000
#
#             Counter     Regulator    Has Python  Has Whiteboard  \
# count  35644.000000  35644.000000  35644.000000    35644.000000
# mean       0.033666      0.005106      0.584979        0.509090
# std        0.180371      0.071275      0.492733        0.499924
# min        0.000000      0.000000      0.000000        0.000000
# 25%        0.000000      0.000000      0.000000        0.000000
# 50%        0.000000      0.000000      1.000000        1.000000
# 75%        0.000000      0.000000      1.000000        1.000000
# max        1.000000      1.000000      1.000000        1.000000
#
#        Has Reached Balmers Peak           DNE  Type of Activity Id  \
# count              35644.000000  35644.000000         35644.000000
# mean                   0.033863      0.177646             0.192119
# std                    0.180878      0.382219             0.109034
# min                    0.000000      0.000000             0.100000
# 25%                    0.000000      0.000000             0.100000
# 50%                    0.000000      0.000000             0.100000
# 75%                    0.000000      0.000000             0.300000
# max                    1.000000      1.000000             0.400000
#
#        Type of Movie Id  Type of GPU Id  Type of Laptop Id  \
# count      35644.000000    35644.000000       35644.000000
# mean           0.181181        0.176220           0.234191
# std            0.138253        0.094821           0.168862
# min            0.100000        0.100000           0.100000
# 25%            0.100000        0.100000           0.100000
# 50%            0.100000        0.200000           0.100000
# 75%            0.200000        0.200000           0.400000
# max            0.600000        0.500000           0.600000
#
#        Type of Toaster Id  Type of Deck Id  Type of Whale Id  Type of Star Id  \
# count        35644.000000     35644.000000      35644.000000     35644.000000
# mean             0.175533         0.207227          0.168270         0.148766
# std              0.098428         0.062349          0.135581         0.083762
# min              0.100000         0.100000          0.100000         0.100000
# 25%              0.100000         0.200000          0.100000         0.100000
# 50%              0.100000         0.200000          0.100000         0.100000
# 75%              0.300000         0.200000          0.100000         0.200000
# max              0.400000         0.400000          0.500000         0.600000
#
#        Type of Dog Id
# count    35644.000000
# mean         0.176571
# std          0.127280
# min          0.100000
# 25%          0.100000
# 50%          0.100000
# 75%          0.300000
# max          0.400000

# %%
df.Status.value_counts()  # Labels
# Out:
# 0.0    2143
# 1.0    1075
# Name: Status, dtype: int64

# %%
df.Status[df.Status.isna()].shape[0]
# Out:
# 32426

# %%
df.head()
# Out:
#    Status  Id  Refreshing  Runner  Baker  Counter  Regulator  Has Python  \
# 0     NaN  25           0       0      0        0          0           1
# 1     1.0  38           0       0      0        0          0           1
# 2     1.0  53           0       0      0        0          0           1
# 3     0.0  61           0       0      0        0          0           0
# 4     0.0  70           0       0      0        0          0           1
#
#    Has Whiteboard  Has Reached Balmers Peak  DNE  Type of Activity Id  \
# 0               1                         0    0                  0.3
# 1               1                         1    0                  0.3
# 2               1                         1    0                  0.3
# 3               0                         0    0                  0.1
# 4               1                         1    0                  0.3
#
#    Type of Movie Id  Type of GPU Id  Type of Laptop Id  Type of Toaster Id  \
# 0               0.4             0.2                0.4                 0.3
# 1               0.4             0.2                0.4                 0.3
# 2               0.3             0.3                0.5                 0.3
# 3               0.1             0.1                0.1                 0.1
# 4               0.6             0.2                0.4                 0.3
#
#    Type of Deck Id  Type of Whale Id  Type of Star Id  Type of Dog Id
# 0              0.3               0.5              0.2             0.4
# 1              0.2               0.1              0.2             0.1
# 2              0.4               0.5              0.2             0.4
# 3              0.1               0.1              0.1             0.1
# 4              0.2               0.5              0.2             0.4

# %% [markdown]
# Convert the numeric into their true types, i.e. categorical variables

# %%
for col in df.columns:
    if col.startswith('Type'):
        df[col] = df[col].apply(lambda x: int(x*10))

# %%
df.head()
# Out:
#    Status  Id  Refreshing  Runner  Baker  Counter  Regulator  Has Python  \
# 0     NaN  25           0       0      0        0          0           1
# 1     1.0  38           0       0      0        0          0           1
# 2     1.0  53           0       0      0        0          0           1
# 3     0.0  61           0       0      0        0          0           0
# 4     0.0  70           0       0      0        0          0           1
#
#    Has Whiteboard  Has Reached Balmers Peak  DNE  Type of Activity Id  \
# 0               1                         0    0                    3
# 1               1                         1    0                    3
# 2               1                         1    0                    3
# 3               0                         0    0                    1
# 4               1                         1    0                    3
#
#    Type of Movie Id  Type of GPU Id  Type of Laptop Id  Type of Toaster Id  \
# 0                 4               2                  4                   3
# 1                 4               2                  4                   3
# 2                 3               3                  5                   3
# 3                 1               1                  1                   1
# 4                 6               2                  4                   3
#
#    Type of Deck Id  Type of Whale Id  Type of Star Id  Type of Dog Id
# 0                3                 5                2               4
# 1                2                 1                2               1
# 2                4                 5                2               4
# 3                1                 1                1               1
# 4                2                 5                2               4

# %%
n_u_nan = [(col, len(df[col].value_counts()), df[col][df[col].isna()].shape[0]) for col in df.columns]
for v in n_u_nan:
    print(f'Col name: {v[0]}, unique vals: {v[1]}, nans: {v[2]}')
# Out:
# Col name: Status, unique vals: 2, nans: 32426
# Col name: Id, unique vals: 35644, nans: 0
# Col name: Refreshing, unique vals: 2, nans: 0
# Col name: Runner, unique vals: 2, nans: 0
# Col name: Baker, unique vals: 2, nans: 0
# Col name: Counter, unique vals: 2, nans: 0
# Col name: Regulator, unique vals: 2, nans: 0
# Col name: Has Python, unique vals: 2, nans: 0
# Col name: Has Whiteboard, unique vals: 2, nans: 0
# Col name: Has Reached Balmers Peak, unique vals: 2, nans: 0
# Col name: DNE, unique vals: 2, nans: 0
# Col name: Type of Activity Id, unique vals: 4, nans: 0
# Col name: Type of Movie Id, unique vals: 6, nans: 0
# Col name: Type of GPU Id, unique vals: 5, nans: 0
# Col name: Type of Laptop Id, unique vals: 6, nans: 0
# Col name: Type of Toaster Id, unique vals: 4, nans: 0
# Col name: Type of Deck Id, unique vals: 4, nans: 0
# Col name: Type of Whale Id, unique vals: 5, nans: 0
# Col name: Type of Star Id, unique vals: 6, nans: 0
# Col name: Type of Dog Id, unique vals: 4, nans: 0

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10, 8))

x_pos = [i for i, _ in enumerate(n_u_nan[2:])]

plt.bar(x_pos, [l[1] for l in n_u_nan[2:]])
plt.xlabel("Columns")
plt.ylabel("Unique vals")
plt.xticks(x_pos, [l[0] for l in n_u_nan[2:]], rotation='vertical')
plt.show()

# %% [markdown]
# Looks all the columns are categorical. That may pose a challenge, as we have a very limited dataset and blowing up the feature set using one-host encoding would likely hurt our ability to make sane predictions.

# %%
# if we were to use One-Hot-Encoding, we'd end up with:
print(sum([i[1] for i in n_u_nan[2:]]), 'columns')
# Out:
# 62 columns

# %% [markdown]
# ### First pass

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from yellowbrick.classifier import ROCAUC

# %%
x, y = df.dropna(subset=['Status']).drop(['Status', 'Id'], 1), df.Status.dropna()

# %%
x.shape, y.shape
# Out:
# ((3218, 18), (3218,))

# %%
rf = RandomForestClassifier()
x_tr, x_te, y_tr, y_te = train_test_split(x, y)

# %%
m = ROCAUC(rf)
m.fit(x_tr, y_tr)
m.score(x_te, y_te)
m.poof()
# Out:
# /Users/carlomazzaferro/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# Close to random

# %%
from sklearn.metrics import classification_report
print(classification_report(y_te, rf.predict(x_te)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.79      0.73       536
#          1.0       0.38      0.25      0.30       269
#
#    micro avg       0.61      0.61      0.61       805
#    macro avg       0.53      0.52      0.52       805
# weighted avg       0.58      0.61      0.59       805

# %% [markdown]
# ## Let's balance out the dataset

# %% [markdown]
# We will be using a technique called Synthetic Minority Oversampling TEchinque (SMOTE) [1]. It performs undersampling on the majority class while generating syntetic data from the undersampled class. The syntetic data is generated by picking the k-nearest neighbors (k set to 5) of the minority class, projects them in a metric space, and picks the point on the centroid of this new space. It can handle categorical variables by using a special distance metric named e Value Difference Metric [2]
#
# 1. https://arxiv.org/pdf/1106.1813.pdf
# 2. https://pdfs.semanticscholar.org/f72c/bf9f16f244f5643273fa04c25e2697fe66b9.pdf

# %%
from imblearn.over_sampling import SMOTE

# %%
rf = RandomForestClassifier()
x_resamp, y_resampled = SMOTE().fit_resample(x, y)
x_tr, x_te, y_tr, y_te = train_test_split(x_resamp, y_resampled)

# %%
m = ROCAUC(rf)
m.fit(x_tr, y_tr)
m.score(x_te, y_te)
m.poof()
# Out:
# /Users/carlomazzaferro/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Welp, that's better

# %%
from sklearn.metrics import classification_report
print(classification_report(y_te, rf.predict(x_te)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.61      0.63       542
#          1.0       0.62      0.66      0.64       530
#
#    micro avg       0.64      0.64      0.64      1072
#    macro avg       0.64      0.64      0.64      1072
# weighted avg       0.64      0.64      0.64      1072

# %% [markdown]
# ### Feature Importances

# %%
from yellowbrick.features.importances import FeatureImportances

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot()

f = FeatureImportances(rf)
x_resamp_df = pandas.DataFrame(x_resamp, columns=x.columns)
y_resampled_df = pandas.Series(y_resampled)
f.fit(x_resamp_df, y_resampled_df, ax=ax)
f.poof()

# %% [markdown]
# Not sure I can draw any conclusions from these... If anything this tells me that pretty much all features are informative, at lest to some degree

# %% [markdown]
# ### One-Hot-Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(categories='auto')
x_ohe = pandas.DataFrame(enc.fit_transform(x_resamp).todense())
x_tr, x_te, y_tr, y_te = train_test_split(x_ohe, y_resampled)

# %%
rf = RandomForestClassifier()
m = ROCAUC(rf)
m.fit(x_tr, y_tr)
m.score(x_te, y_te)
m.poof()
# Out:
# /Users/carlomazzaferro/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Steady improvements!

# %%
from sklearn.metrics import classification_report
print(classification_report(y_te, rf.predict(x_te)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.63      0.65       540
#          1.0       0.65      0.68      0.66       532
#
#    micro avg       0.66      0.66      0.66      1072
#    macro avg       0.66      0.66      0.66      1072
# weighted avg       0.66      0.66      0.66      1072

# %% [markdown]
# ### Hyperparameter Search

# %% [markdown]
# Let's start by optimizing the integer-valued parameters. I'll still be using randomized search because it is simply just faster and we have a time constraint here.
#
# *although if we had more time I'd surely use grid search for fine grained search*

# %%
import numpy
from sklearn.model_selection import RandomizedSearchCV


random_grid = {'n_estimators': [int(x) for x in numpy.linspace(start = 1000, stop = 2000, num = 10)],
               'max_features': [None, 'sqrt', 'log2'],
               'max_depth': [int(x) for x in numpy.linspace(40, 110, num = 11)] + [None],
               'min_samples_split': [3, 5, 7, 9],
               'min_samples_leaf': [1, 2, 3],
               'bootstrap': [True, False]}

rf_random = RandomizedSearchCV(estimator=rf, 
                               param_distributions=random_grid, 
                               n_iter=100, 
                               cv=3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs=8)

rf_random.fit(x_ohe, y_resampled)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1400,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 80,
#  'bootstrap': False}

# %%
r_optimized = rf.set_params(**rf_random.best_params_)

# %%
m = ROCAUC(r_optimized)
m.fit(x_tr, y_tr)
m.score(x_te, y_te)
m.poof()

# %%
# Moaaar improvements

# %%
from sklearn.metrics import classification_report
print(classification_report(y_te, r_optimized.predict(x_te)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.67      0.66       538
#          1.0       0.65      0.63      0.64       534
#
#    micro avg       0.65      0.65      0.65      1072
#    macro avg       0.65      0.65      0.65      1072
# weighted avg       0.65      0.65      0.65      1072

# %% [markdown]
# ### Hyperparameter Search - Continued

# %%
random_grid = {
  'min_weight_fraction_leaf': [0, 0.0001, 0.0002, 0.003],
  'min_impurity_decrease': [0, 0.0001, 0.0002, 0.003],
  'n_estimators': [1400],
  'min_samples_split': [5],
  'min_samples_leaf': [1],
  'max_features': ['sqrt'],
  'max_depth': [80],
  'bootstrap': [False]}

rf_random = RandomizedSearchCV(estimator=rf, 
                               param_distributions=random_grid, 
                               n_iter=100, 
                               cv=3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs=8)

rf_random.fit(x_ohe, y_resampled)
# Out:
# /Users/carlomazzaferro/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/model_selection/_search.py:271: UserWarning: The total space of parameters 16 is smaller than n_iter=100. Running 16 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=8)]: Done  48 out of  48 | elapsed:   39.7s finished
# RandomizedSearchCV(cv=3, error_score='raise-deprecating',
#           estimator=RandomForestClassifier(bootstrap=False, class_weight=None, criterion='gini',
#             max_depth=80, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1400, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#           fit_params=None, iid='warn', n_iter=100, n_jobs=8,
#           param_distributions={'min_weight_fraction_leaf': [0, 0.0001, 0.0002, 0.003], 'min_impurity_decrease': [0, 0.0001, 0.0002, 0.003], 'n_estimators': [1400], 'min_samples_split': [5], 'min_samples_leaf': [1], 'max_features': ['sqrt'], 'max_depth': [80], 'bootstrap': [False]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score='warn', scoring=None, verbose=2)

# %%
rf = RandomForestClassifier()
r_optimized = rf.set_params(**rf_random.best_params_)
m = ROCAUC(r_optimized)
m.fit(x_tr, y_tr)
m.score(x_te, y_te)
m.poof()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_te, r_optimized.predict(x_te)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-51156d22cb76> in <module>
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(y_te, r_optimized.predict(x_te)))
#
# ~/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     541             The predicted classes.
#     542         """
# --> 543         proba = self.predict_proba(X)
#     544
#     545         if self.n_outputs_ == 1:
#
# ~/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     581         check_is_fitted(self, 'estimators_')
#     582         # Check data
# --> 583         X = self._validate_X_predict(X)
#     584
#     585         # Assign chunk of trees to jobs
#
# ~/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     360                                  "call `fit` before exploiting the model.")
#     361
# --> 362         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     363
#     364     @property
#
# ~/.virtualenvs/facet/lib/python3.6/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     386                              "match the input. Model n_features is %s and "
#     387                              "input n_features is %s "
# --> 388                              % (self.n_features_, n_features))
#     389
#     390         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 62 and input n_features is 18

# %%
# Very minor improvements, but still improving. Alright we're done here.
